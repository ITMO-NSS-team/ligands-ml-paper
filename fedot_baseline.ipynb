# %%
from utils import seed_everything
from utils import load_datasets
from fedot import Fedot
from fedot.core.pipelines.pipeline_builder import PipelineBuilder
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
import numpy as np
from typing import Tuple, Dict
import pandas as pd
from sklearn.feature_selection import VarianceThreshold

SEED = 42
seed_everything(SEED)
datasets = load_datasets("Gd_fps")

# %%
lgbm_kwargs = dict(
    n_estimators=600,
    learning_rate=0.03,
    num_leaves=15,
    min_data_in_leaf=5,
    feature_fraction=0.7,
    bagging_fraction=0.8,
    bagging_freq=1,
    reg_alpha=0.0,
    reg_lambda=1.0,
    random_state=SEED
)

# %%
def prepare_data(
    df: pd.DataFrame,
    target_col: str = "lgK",
    test_size: float = 0.2,
    random_state: int = 42
) -> Tuple[np.ndarray, np.ndarray, np.ndarray, np.ndarray]:
    feature_cols = [c for c in df.columns if c != target_col]
    X = df[feature_cols].astype(np.float32).values
    y = df[target_col].values

    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=test_size, random_state=random_state
    )
    
    vt = VarianceThreshold(threshold=0.0)
    X_train = vt.fit_transform(X_train)
    X_test = vt.transform(X_test)
    
    return X_train, X_test, y_train, y_test

def train_model(X_train, y_train):
    model = Fedot(
        problem='regression',
        timeout=1,
        n_jobs=-1,
        logging_level=20,
        seed=SEED,
    )
    model.fit(
        X_train, 
        y_train, 
        predefined_model=PipelineBuilder().add_node('lgbmreg', params=lgbm_kwargs).build()
    )
    return model


# -------------------------
# 4) Evaluation (hold-out)
# -------------------------

def evaluate_model(model, X_test, y_test) -> Dict[str, float]:
    """
    Evaluate a trained model on hold-out data; print metrics.
    """
    y_pred = model.predict(X_test)
    rmse = mean_squared_error(y_test, y_pred, squared=False)
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    print(f"RMSE: {rmse:.4f} | MAE: {mae:.4f} | R²: {r2:.4f}")
    return {"RMSE": rmse, "MAE": mae, "R2": r2}

# %%
def run_final_pipeline(df: pd.DataFrame, target_col: str = "lgK", random_state: int = 42):
    X_train, X_test, y_train, y_test = prepare_data(df, target_col=target_col, random_state=random_state)
    fedot_fitted = train_model(X_train, y_train)
    print("\nHold-out performance:")
    metrics = evaluate_model(fedot_fitted, X_test, y_test)
    return fedot_fitted, metrics

# %%
all_metrics = {}
for name, df in datasets.items():
    print(f"\nDataset: {name}")
    _, metrics = run_final_pipeline(df, target_col="lgK", random_state=SEED)
    all_metrics[name] = metrics
metrics_df = pd.DataFrame(all_metrics).T
# Out:
# Dataset: Gd_ctopo_fp_cmplx
# 2025-10-10 16:47:29,637 - TableTypesCorrector - Preprocessing was unable to define the categorical columns
# 2025-10-10 16:47:33,356 - FEDOT logger - Final pipeline: {'depth': 1, 'length': 1, 'nodes': [lgbmreg]}
# lgbmreg - {'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.8, 'extra_trees': False, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'n_jobs': 1, 'verbose': -1, 'n_estimators': 600, 'learning_rate': 0.03, 'num_leaves': 15, 'min_data_in_leaf': 5, 'feature_fraction': 0.7, 'bagging_freq': 1, 'reg_alpha': 0.0, 'reg_lambda': 1.0, 'random_state': 42}
# 2025-10-10 16:47:33,361 - MemoryAnalytics - Memory consumption for finish in main session: current 55.1 MiB, max: 60.5 MiB
#
# Hold-out performance:
# RMSE: 3.9088 | MAE: 3.2090 | R²: 0.2125
#
# Dataset: Gd_ctopo_fp_cmplx_da
# 2025-10-10 16:47:35,701 - TableTypesCorrector - Preprocessing was unable to define the categorical columns
# 2025-10-10 16:47:38,692 - FEDOT logger - Final pipeline: {'depth': 1, 'length': 1, 'nodes': [lgbmreg]}
# lgbmreg - {'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.8, 'extra_trees': False, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'n_jobs': 1, 'verbose': -1, 'n_estimators': 600, 'learning_rate': 0.03, 'num_leaves': 15, 'min_data_in_leaf': 5, 'feature_fraction': 0.7, 'bagging_freq': 1, 'reg_alpha': 0.0, 'reg_lambda': 1.0, 'random_state': 42}
# 2025-10-10 16:47:38,695 - MemoryAnalytics - Memory consumption for finish in main session: current 4.3 MiB, max: 8.3 MiB
#
# Hold-out performance:
# RMSE: 3.8139 | MAE: 3.1185 | R²: 0.2502
#
# Dataset: Gd_ctopo_fp_cmplx_da_bonds
# 2025-10-10 16:47:40,305 - TableTypesCorrector - Preprocessing was unable to define the categorical columns
# 2025-10-10 16:47:42,920 - FEDOT logger - Final pipeline: {'depth': 1, 'length': 1, 'nodes': [lgbmreg]}
# lgbmreg - {'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.8, 'extra_trees': False, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'n_jobs': 1, 'verbose': -1, 'n_estimators': 600, 'learning_rate': 0.03, 'num_leaves': 15, 'min_data_in_leaf': 5, 'feature_fraction': 0.7, 'bagging_freq': 1, 'reg_alpha': 0.0, 'reg_lambda': 1.0, 'random_state': 42}
# 2025-10-10 16:47:42,923 - MemoryAnalytics - Memory consumption for finish in main session: current 4.3 MiB, max: 8.6 MiB
#
# Hold-out performance:
# RMSE: 3.8108 | MAE: 3.1129 | R²: 0.2514
#
# Dataset: Gd_ctopo_fp_cmplx_da_sub
# 2025-10-10 16:47:44,867 - TableTypesCorrector - Preprocessing was unable to define the categorical columns
# 2025-10-10 16:47:48,216 - FEDOT logger - Final pipeline: {'depth': 1, 'length': 1, 'nodes': [lgbmreg]}
# lgbmreg - {'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.8, 'extra_trees': False, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'n_jobs': 1, 'verbose': -1, 'n_estimators': 600, 'learning_rate': 0.03, 'num_leaves': 15, 'min_data_in_leaf': 5, 'feature_fraction': 0.7, 'bagging_freq': 1, 'reg_alpha': 0.0, 'reg_lambda': 1.0, 'random_state': 42}
# 2025-10-10 16:47:48,221 - MemoryAnalytics - Memory consumption for finish in main session: current 4.7 MiB, max: 9.4 MiB
#
# Hold-out performance:
# RMSE: 3.7806 | MAE: 3.0383 | R²: 0.2632
#
# Dataset: Gd_ctopo_fp_cmplx_da_sub_bonds
# 2025-10-10 16:47:50,487 - TableTypesCorrector - Preprocessing was unable to define the categorical columns
# 2025-10-10 16:47:54,252 - FEDOT logger - Final pipeline: {'depth': 1, 'length': 1, 'nodes': [lgbmreg]}
# lgbmreg - {'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.8, 'extra_trees': False, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'n_jobs': 1, 'verbose': -1, 'n_estimators': 600, 'learning_rate': 0.03, 'num_leaves': 15, 'min_data_in_leaf': 5, 'feature_fraction': 0.7, 'bagging_freq': 1, 'reg_alpha': 0.0, 'reg_lambda': 1.0, 'random_state': 42}
# 2025-10-10 16:47:54,256 - MemoryAnalytics - Memory consumption for finish in main session: current 4.8 MiB, max: 9.4 MiB
#
# Hold-out performance:
# RMSE: 3.5938 | MAE: 2.9609 | R²: 0.3343
#
# Dataset: Gd_ctopo_fp_cmplx_full
# 2025-10-10 16:47:56,528 - TableTypesCorrector - Preprocessing was unable to define the categorical columns
# 2025-10-10 16:47:59,718 - FEDOT logger - Final pipeline: {'depth': 1, 'length': 1, 'nodes': [lgbmreg]}
# lgbmreg - {'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.8, 'extra_trees': False, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'n_jobs': 1, 'verbose': -1, 'n_estimators': 600, 'learning_rate': 0.03, 'num_leaves': 15, 'min_data_in_leaf': 5, 'feature_fraction': 0.7, 'bagging_freq': 1, 'reg_alpha': 0.0, 'reg_lambda': 1.0, 'random_state': 42}
# 2025-10-10 16:47:59,721 - MemoryAnalytics - Memory consumption for finish in main session: current 4.7 MiB, max: 9.3 MiB
#
# Hold-out performance:
# RMSE: 3.7425 | MAE: 3.0733 | R²: 0.2780
#
# Dataset: Gd_ctopo_fp_ligand
# 2025-10-10 16:48:01,318 - TableTypesCorrector - Preprocessing was unable to define the categorical columns
# 2025-10-10 16:48:03,715 - FEDOT logger - Final pipeline: {'depth': 1, 'length': 1, 'nodes': [lgbmreg]}
# lgbmreg - {'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.8, 'extra_trees': False, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'n_jobs': 1, 'verbose': -1, 'n_estimators': 600, 'learning_rate': 0.03, 'num_leaves': 15, 'min_data_in_leaf': 5, 'feature_fraction': 0.7, 'bagging_freq': 1, 'reg_alpha': 0.0, 'reg_lambda': 1.0, 'random_state': 42}
# 2025-10-10 16:48:03,718 - MemoryAnalytics - Memory consumption for finish in main session: current 3.9 MiB, max: 7.7 MiB
#
# Hold-out performance:
# RMSE: 3.9004 | MAE: 3.0981 | R²: 0.2158
#
# Dataset: Gd_ctopo_fp_skl
# 2025-10-10 16:48:04,487 - TableTypesCorrector - Preprocessing was unable to define the categorical columns
# 2025-10-10 16:48:04,909 - FEDOT logger - Final pipeline: {'depth': 1, 'length': 1, 'nodes': [lgbmreg]}
# lgbmreg - {'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.8, 'extra_trees': False, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'n_jobs': 1, 'verbose': -1, 'n_estimators': 600, 'learning_rate': 0.03, 'num_leaves': 15, 'min_data_in_leaf': 5, 'feature_fraction': 0.7, 'bagging_freq': 1, 'reg_alpha': 0.0, 'reg_lambda': 1.0, 'random_state': 42}
# 2025-10-10 16:48:04,912 - MemoryAnalytics - Memory consumption for finish in main session: current 0.7 MiB, max: 2.7 MiB
#
# Hold-out performance:
# RMSE: 3.9782 | MAE: 3.1514 | R²: 0.1842
#
# Dataset: Gd_ctopo_fp_skl_da
# 2025-10-10 16:48:05,382 - TableTypesCorrector - Preprocessing was unable to define the categorical columns
# 2025-10-10 16:48:05,992 - FEDOT logger - Final pipeline: {'depth': 1, 'length': 1, 'nodes': [lgbmreg]}
# lgbmreg - {'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.8, 'extra_trees': False, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'n_jobs': 1, 'verbose': -1, 'n_estimators': 600, 'learning_rate': 0.03, 'num_leaves': 15, 'min_data_in_leaf': 5, 'feature_fraction': 0.7, 'bagging_freq': 1, 'reg_alpha': 0.0, 'reg_lambda': 1.0, 'random_state': 42}
# 2025-10-10 16:48:05,996 - MemoryAnalytics - Memory consumption for finish in main session: current 1.0 MiB, max: 2.9 MiB
#
# Hold-out performance:
# RMSE: 4.0443 | MAE: 3.1881 | R²: 0.1569
#
# Dataset: Gd_ctopo_fp_skl_da_bonds
# 2025-10-10 16:48:06,500 - TableTypesCorrector - Preprocessing was unable to define the categorical columns
# 2025-10-10 16:48:07,230 - FEDOT logger - Final pipeline: {'depth': 1, 'length': 1, 'nodes': [lgbmreg]}
# lgbmreg - {'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.8, 'extra_trees': False, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'n_jobs': 1, 'verbose': -1, 'n_estimators': 600, 'learning_rate': 0.03, 'num_leaves': 15, 'min_data_in_leaf': 5, 'feature_fraction': 0.7, 'bagging_freq': 1, 'reg_alpha': 0.0, 'reg_lambda': 1.0, 'random_state': 42}
# 2025-10-10 16:48:07,233 - MemoryAnalytics - Memory consumption for finish in main session: current 1.2 MiB, max: 3.4 MiB
#
# Hold-out performance:
# RMSE: 3.9020 | MAE: 3.0211 | R²: 0.2152
#
# Dataset: Gd_ctopo_fp_skl_da_skl
# 2025-10-10 16:48:07,793 - TableTypesCorrector - Preprocessing was unable to define the categorical columns
# 2025-10-10 16:48:08,537 - FEDOT logger - Final pipeline: {'depth': 1, 'length': 1, 'nodes': [lgbmreg]}
# lgbmreg - {'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.8, 'extra_trees': False, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'n_jobs': 1, 'verbose': -1, 'n_estimators': 600, 'learning_rate': 0.03, 'num_leaves': 15, 'min_data_in_leaf': 5, 'feature_fraction': 0.7, 'bagging_freq': 1, 'reg_alpha': 0.0, 'reg_lambda': 1.0, 'random_state': 42}
# 2025-10-10 16:48:08,540 - MemoryAnalytics - Memory consumption for finish in main session: current 1.2 MiB, max: 3.3 MiB
#
# Hold-out performance:
# RMSE: 4.0297 | MAE: 3.2533 | R²: 0.1630
#
# Dataset: Gd_ctopo_fp_skl_da_skl_bonds
# 2025-10-10 16:48:09,155 - TableTypesCorrector - Preprocessing was unable to define the categorical columns
# 2025-10-10 16:48:10,010 - FEDOT logger - Final pipeline: {'depth': 1, 'length': 1, 'nodes': [lgbmreg]}
# lgbmreg - {'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.8, 'extra_trees': False, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'n_jobs': 1, 'verbose': -1, 'n_estimators': 600, 'learning_rate': 0.03, 'num_leaves': 15, 'min_data_in_leaf': 5, 'feature_fraction': 0.7, 'bagging_freq': 1, 'reg_alpha': 0.0, 'reg_lambda': 1.0, 'random_state': 42}
# 2025-10-10 16:48:10,013 - MemoryAnalytics - Memory consumption for finish in main session: current 1.4 MiB, max: 3.7 MiB
#
# Hold-out performance:
# RMSE: 3.9932 | MAE: 3.1050 | R²: 0.1780
#
# Dataset: Gd_ctopo_fp_topo
# 2025-10-10 16:48:10,454 - TableTypesCorrector - Preprocessing was unable to define the categorical columns
# 2025-10-10 16:48:11,046 - FEDOT logger - Final pipeline: {'depth': 1, 'length': 1, 'nodes': [lgbmreg]}
# lgbmreg - {'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.8, 'extra_trees': False, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'n_jobs': 1, 'verbose': -1, 'n_estimators': 600, 'learning_rate': 0.03, 'num_leaves': 15, 'min_data_in_leaf': 5, 'feature_fraction': 0.7, 'bagging_freq': 1, 'reg_alpha': 0.0, 'reg_lambda': 1.0, 'random_state': 42}
# 2025-10-10 16:48:11,049 - MemoryAnalytics - Memory consumption for finish in main session: current 0.8 MiB, max: 2.7 MiB
#
# Hold-out performance:
# RMSE: 4.3291 | MAE: 3.6009 | R²: 0.0340
#
# Dataset: Gd_ctopo_fp_topo_da
# 2025-10-10 16:48:11,588 - TableTypesCorrector - Preprocessing was unable to define the categorical columns
# 2025-10-10 16:48:12,263 - FEDOT logger - Final pipeline: {'depth': 1, 'length': 1, 'nodes': [lgbmreg]}
# lgbmreg - {'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.8, 'extra_trees': False, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'n_jobs': 1, 'verbose': -1, 'n_estimators': 600, 'learning_rate': 0.03, 'num_leaves': 15, 'min_data_in_leaf': 5, 'feature_fraction': 0.7, 'bagging_freq': 1, 'reg_alpha': 0.0, 'reg_lambda': 1.0, 'random_state': 42}
# 2025-10-10 16:48:12,266 - MemoryAnalytics - Memory consumption for finish in main session: current 1.2 MiB, max: 3.1 MiB
#
# Hold-out performance:
# RMSE: 4.3191 | MAE: 3.4026 | R²: 0.0384

# %%
metrics_df
# Out:
#                                     RMSE       MAE        R2
# Gd_ctopo_fp_cmplx               3.908762  3.209043  0.212458
# Gd_ctopo_fp_cmplx_da            3.813934  3.118467  0.250206
# Gd_ctopo_fp_cmplx_da_bonds      3.810822  3.112918  0.251429
# Gd_ctopo_fp_cmplx_da_sub        3.780636  3.038336  0.263241
# Gd_ctopo_fp_cmplx_da_sub_bonds  3.593826  2.960939  0.334252
# Gd_ctopo_fp_cmplx_full          3.742468  3.073256  0.278042
# Gd_ctopo_fp_ligand              3.900381  3.098070  0.215831
# Gd_ctopo_fp_skl                 3.978201  3.151416  0.184227
# Gd_ctopo_fp_skl_da              4.044272  3.188086  0.156906
# Gd_ctopo_fp_skl_da_bonds        3.901985  3.021110  0.215186
# Gd_ctopo_fp_skl_da_skl          4.029724  3.253321  0.162960
# Gd_ctopo_fp_skl_da_skl_bonds    3.993241  3.104977  0.178048
# Gd_ctopo_fp_topo                4.329089  3.600897  0.033975
# Gd_ctopo_fp_topo_da             4.319136  3.402570  0.038411

# %%
X_train, X_test, y_train, y_test = prepare_data(datasets["Gd_ctopo_fp_cmplx"], target_col="lgK", random_state=SEED)
model = Fedot(
        problem='regression',
        timeout=1,
        n_jobs=-1,
        logging_level=20,
        seed=SEED,
        use_input_preprocessing=False
    )
model.fit(
    X_train, 
    y_train, 
    predefined_model=PipelineBuilder().add_node('lgbmreg', params=lgbm_kwargs).build()
)
# Out:
# 2025-10-13 13:29:36,681 - Topological features operation requires extra dependencies for time series forecasting, which are not installed. It can infuence the performance. Please install it by 'pip install fedot[extra]'
# 2025-10-13 13:29:36,757 - FEDOT logger - Predefined model fit was failed due to: object of type 'NoneType' has no len().
# Traceback (most recent call last):
#   File "D:\python_projects\ligands-ml-paper\venv\lib\site-packages\fedot\api\api_utils\predefined_model.py", line 54, in fit
#     self.pipeline.fit(self.data)
#   File "D:\python_projects\ligands-ml-paper\venv\lib\site-packages\fedot\core\pipelines\pipeline.py", line 191, in fit
#     copied_input_data = self._preprocess(input_data)
#   File "D:\python_projects\ligands-ml-paper\venv\lib\site-packages\fedot\core\pipelines\pipeline.py", line 140, in _preprocess
#     copied_input_data = self.preprocessor.optional_prepare_for_fit(pipeline=self, data=copied_input_data)
#   File "D:\python_projects\ligands-ml-paper\venv\lib\site-packages\fedot\preprocessing\preprocessing.py", line 141, in optional_prepare_for_fit
#     self._prepare_optional(pipeline, data, DEFAULT_SOURCE_NAME)
#   File "D:\python_projects\ligands-ml-paper\venv\lib\site-packages\fedot\preprocessing\preprocessing.py", line 277, in _prepare_optional
#     if has_problems(data):
#   File "D:\python_projects\ligands-ml-paper\venv\lib\site-packages\fedot\core\data\data_preprocessing.py", line 104, in data_has_categorical_features
#     if len(cat_ids) > 0:
# TypeError: object of type 'NoneType' has no len()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File D:\python_projects\ligands-ml-paper\venv\lib\site-packages\fedot\api\api_utils\predefined_model.py:54, in PredefinedModel.fit(self)
#      53 try:
# ---> 54     self.pipeline.fit(self.data)
#      55 except Exception as ex:
#
# File D:\python_projects\ligands-ml-paper\venv\lib\site-packages\fedot\core\pipelines\pipeline.py:191, in Pipeline.fit(self, input_data, time_constraint, n_jobs)
#     190     with fedot_composer_timer.launch_preprocessing():
# --> 191         copied_input_data = self._preprocess(input_data)
#     193 copied_input_data = self._assign_data_to_nodes(copied_input_data)
#
# File D:\python_projects\ligands-ml-paper\venv\lib\site-packages\fedot\core\pipelines\pipeline.py:140, in Pipeline._preprocess(self, input_data, is_fit_stage)
#     139 # Make additional preprocessing if it is needed
# --> 140 copied_input_data = self.preprocessor.optional_prepare_for_fit(pipeline=self, data=copied_input_data)
#     141 copied_input_data = self.preprocessor.convert_indexes_for_fit(pipeline=self, data=copied_input_data)
#
# File D:\python_projects\ligands-ml-paper\venv\lib\site-packages\fedot\preprocessing\preprocessing.py:141, in DataPreprocessor.optional_prepare_for_fit(self, pipeline, data)
#     140 if isinstance(data, InputData):
# --> 141     self._prepare_optional(pipeline, data, DEFAULT_SOURCE_NAME)
#     142 else:
#     143     # Multimodal data
#
# File D:\python_projects\ligands-ml-paper\venv\lib\site-packages\fedot\preprocessing\preprocessing.py:277, in DataPreprocessor._prepare_optional(self, pipeline, data, source_name)
#     276 self.log.debug(f'Deciding to apply {tag_to_check} for data')
# --> 277 if has_problems(data):
#     278     self.log.debug(f'Finding {tag_to_check} is required and trying to apply')
#
# File D:\python_projects\ligands-ml-paper\venv\lib\site-packages\fedot\core\data\data_preprocessing.py:104, in data_has_categorical_features(data)
#     102 cat_ids, _ = data.categorical_idx, data.numerical_idx
# --> 104 if len(cat_ids) > 0:
#     105     data.categorical_features = data.features[:, cat_ids]
#
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 10
#       1 X_train, X_test, y_train, y_test = prepare_data(datasets["Gd_ctopo_fp_cmplx"], target_col="lgK", random_state=SEED)
#       2 model = Fedot(
#       3         problem='regression',
#       4         timeout=1,
#    (...)
#       8         use_input_preprocessing=False
#       9     )
# ---> 10 model.fit(
#      11     X_train,
#      12     y_train,
#      13     predefined_model=PipelineBuilder().add_node('lgbmreg', params=lgbm_kwargs).build()
#      14 )
#
# File D:\python_projects\ligands-ml-paper\venv\lib\site-packages\fedot\api\main.py:183, in Fedot.fit(self, features, target, predefined_model)
#     176 with fedot_composer_timer.launch_fitting():
#     177     if predefined_model is not None:
#     178         # Fit predefined model and return it without composing
#     179         self.current_pipeline = PredefinedModel(
#     180             predefined_model, self.train_data, self.log,
#     181             use_input_preprocessing=self.params.get('use_input_preprocessing'),
#     182             api_preprocessor=self.data_processor.preprocessor,
# --> 183         ).fit()
#     184     else:
#     185         self.current_pipeline, self.best_models, self.history = self.api_composer.obtain_model(self.train_data)
#
# File D:\python_projects\ligands-ml-paper\venv\lib\site-packages\fedot\api\api_utils\predefined_model.py:60, in PredefinedModel.fit(self)
#      58     self.log.message(fit_failed_info)
#      59     print(traceback.format_exc())
# ---> 60     raise ValueError(advice_info)
#      61 return self.pipeline
#
# ValueError: Predefined model fit was failed due to: object of type 'NoneType' has no len(). Check pipeline structure and the correctness of the data
